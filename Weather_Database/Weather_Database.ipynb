# %%
# Import the dependencies.
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
from citipy import citipy
# Import the time library and the datetime module from the datetime library 
import time
from datetime import datetime
# Import the requests library.
import requests
# Import the API key.
from config import weather_api_key

# %%
# Starting URL for Weather Map API Call.
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key

# %%
# Create a set of random latitude and longitude combinations.
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)
lat_lngs = zip(lats, lngs)
lat_lngs

# %%
# Add the latitudes and longitudes to a list.(unpack zip)
coordinates = list(lat_lngs)
# Create a list for holding the cities.
cities = []
# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)

# %%
len(cities)
# Out:
# 761

# %%
# Create an empty list to hold the weather data.
city_data = []
# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1
# Loop through all the cities in the list.
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
        time.sleep(60)

    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")
    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1
    # Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        city_weather_description = city_weather["weather"][0]["description"]

        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Current Description": city_weather_description})

# If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | taolanaro
# City not found. Skipping...
# Processing Record 2 of Set 1 | kirkwall
# Processing Record 3 of Set 1 | mys shmidta
# City not found. Skipping...
# Processing Record 4 of Set 1 | jardim
# Processing Record 5 of Set 1 | kapaa
# Processing Record 6 of Set 1 | pangnirtung
# Processing Record 7 of Set 1 | busselton
# Processing Record 8 of Set 1 | rikitea
# Processing Record 9 of Set 1 | punta arenas
# Processing Record 10 of Set 1 | airai
# Processing Record 11 of Set 1 | te anau
# Processing Record 12 of Set 1 | lata
# Processing Record 13 of Set 1 | vaini
# Processing Record 14 of Set 1 | matcha
# Processing Record 15 of Set 1 | clyde river
# Processing Record 16 of Set 1 | talnakh
# Processing Record 17 of Set 1 | jamestown
# Processing Record 18 of Set 1 | flinders
# Processing Record 19 of Set 1 | ambon
# Processing Record 20 of Set 1 | naze
# Processing Record 21 of Set 1 | longyearbyen
# Processing Record 22 of Set 1 | ushuaia
# Processing Record 23 of Set 1 | pevek
# Processing Record 24 of Set 1 | wanning
# Processing Record 25 of Set 1 | pimentel
# Processing Record 26 of Set 1 | sorland
# Processing Record 27 of Set 1 | los llanos de aridane
# Processing Record 28 of Set 1 | hilo
# Processing Record 29 of Set 1 | ginda
# Processing Record 30 of Set 1 | avarua
# Processing Record 31 of Set 1 | fort-shevchenko
# Processing Record 32 of Set 1 | namibe
# Processing Record 33 of Set 1 | sitka
# Processing Record 34 of Set 1 | pemangkat
# Processing Record 35 of Set 1 | saint george
# Processing Record 36 of Set 1 | margate
# Processing Record 37 of Set 1 | mataura
# Processing Record 38 of Set 1 | ancud
# Processing Record 39 of Set 1 | nikolskoye
# Processing Record 40 of Set 1 | nazas
# Processing Record 41 of Set 1 | nurota
# Processing Record 42 of Set 1 | iqaluit
# Processing Record 43 of Set 1 | mehamn
# Processing Record 44 of Set 1 | hermanus
# Processing Record 45 of Set 1 | atherton
# Processing Record 46 of Set 1 | mahebourg
# Processing Record 47 of Set 1 | lake havasu city
# Processing Record 48 of Set 1 | korla
# Processing Record 49 of Set 1 | esperance
# Processing Record 50 of Set 1 | barroualie
# City not found. Skipping...
# Processing Record 1 of Set 2 | bethel
# Processing Record 2 of Set 2 | lompoc
# Processing Record 3 of Set 2 | omsk
# Processing Record 4 of Set 2 | ilulissat
# Processing Record 5 of Set 2 | macaboboni
# City not found. Skipping...
# Processing Record 6 of Set 2 | minbu
# Processing Record 7 of Set 2 | khatanga
# Processing Record 8 of Set 2 | sisophon
# Processing Record 9 of Set 2 | victoria
# Processing Record 10 of Set 2 | muromtsevo
# Processing Record 11 of Set 2 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 12 of Set 2 | hambantota
# Processing Record 13 of Set 2 | pedasi
# Processing Record 14 of Set 2 | norman wells
# Processing Record 15 of Set 2 | nacunday
# City not found. Skipping...
# Processing Record 16 of Set 2 | pangai
# Processing Record 17 of Set 2 | bredasdorp
# Processing Record 18 of Set 2 | xining
# Processing Record 19 of Set 2 | wahiawa
# Processing Record 20 of Set 2 | qaanaaq
# Processing Record 21 of Set 2 | saint-leu
# Processing Record 22 of Set 2 | new norfolk
# Processing Record 23 of Set 2 | san quintin
# Processing Record 24 of Set 2 | ugento
# Processing Record 25 of Set 2 | sept-iles
# Processing Record 26 of Set 2 | bud
# Processing Record 27 of Set 2 | cosala
# Processing Record 28 of Set 2 | mount darwin
# Processing Record 29 of Set 2 | bratsk
# Processing Record 30 of Set 2 | san leandro
# Processing Record 31 of Set 2 | port alfred
# Processing Record 32 of Set 2 | hovd
# Processing Record 33 of Set 2 | labuhan
# Processing Record 34 of Set 2 | mar del plata
# Processing Record 35 of Set 2 | pasni
# Processing Record 36 of Set 2 | salalah
# Processing Record 37 of Set 2 | pacific grove
# Processing Record 38 of Set 2 | mapiripan
# Processing Record 39 of Set 2 | biak
# Processing Record 40 of Set 2 | golspie
# Processing Record 41 of Set 2 | luanda
# Processing Record 42 of Set 2 | hithadhoo
# Processing Record 43 of Set 2 | itoman
# Processing Record 44 of Set 2 | channel-port aux basques
# Processing Record 45 of Set 2 | wadena
# Processing Record 46 of Set 2 | puerto escondido
# Processing Record 47 of Set 2 | lebu
# Processing Record 48 of Set 2 | dingle
# Processing Record 49 of Set 2 | tsihombe
# City not found. Skipping...
# Processing Record 50 of Set 2 | agapovka
# Processing Record 1 of Set 3 | narsaq
# Processing Record 2 of Set 3 | yellowknife
# Processing Record 3 of Set 3 | nizhneyansk
# City not found. Skipping...
# Processing Record 4 of Set 3 | hasaki
# Processing Record 5 of Set 3 | egvekinot
# Processing Record 6 of Set 3 | lolua
# City not found. Skipping...
# Processing Record 7 of Set 3 | upernavik
# Processing Record 8 of Set 3 | dikson
# Processing Record 9 of Set 3 | tasiilaq
# Processing Record 10 of Set 3 | madang
# Processing Record 11 of Set 3 | petropavlovsk-kamchatskiy
# Processing Record 12 of Set 3 | atuona
# Processing Record 13 of Set 3 | rio gallegos
# Processing Record 14 of Set 3 | kahului
# Processing Record 15 of Set 3 | cuamba
# Processing Record 16 of Set 3 | albany
# Processing Record 17 of Set 3 | cape town
# Processing Record 18 of Set 3 | hobart
# Processing Record 19 of Set 3 | broken hill
# Processing Record 20 of Set 3 | hohhot
# Processing Record 21 of Set 3 | passo fundo
# Processing Record 22 of Set 3 | barrow
# Processing Record 23 of Set 3 | tiksi
# Processing Record 24 of Set 3 | severo-kurilsk
# Processing Record 25 of Set 3 | port lincoln
# Processing Record 26 of Set 3 | husavik
# Processing Record 27 of Set 3 | carnarvon
# Processing Record 28 of Set 3 | belushya guba
# City not found. Skipping...
# Processing Record 29 of Set 3 | padang
# Processing Record 30 of Set 3 | kiunga
# Processing Record 31 of Set 3 | kieta
# Processing Record 32 of Set 3 | puerto ayora
# Processing Record 33 of Set 3 | butaritari
# Processing Record 34 of Set 3 | tamiahua
# Processing Record 35 of Set 3 | mount gambier
# Processing Record 36 of Set 3 | saskylakh
# Processing Record 37 of Set 3 | ribeira grande
# Processing Record 38 of Set 3 | santa isabel
# Processing Record 39 of Set 3 | gravdal
# Processing Record 40 of Set 3 | vaitupu
# City not found. Skipping...
# Processing Record 41 of Set 3 | ostrovnoy
# Processing Record 42 of Set 3 | dzaoudzi
# Processing Record 43 of Set 3 | samalaeulu
# City not found. Skipping...
# Processing Record 44 of Set 3 | blackfoot
# Processing Record 45 of Set 3 | provideniya
# Processing Record 46 of Set 3 | lilongwe
# Processing Record 47 of Set 3 | port elizabeth
# Processing Record 48 of Set 3 | mozarlandia
# Processing Record 49 of Set 3 | khormuj
# City not found. Skipping...
# Processing Record 50 of Set 3 | fort nelson
# Processing Record 1 of Set 4 | gat
# Processing Record 2 of Set 4 | bontang
# Processing Record 3 of Set 4 | aklavik
# Processing Record 4 of Set 4 | uglovskoye
# Processing Record 5 of Set 4 | bajil
# Processing Record 6 of Set 4 | buritis
# Processing Record 7 of Set 4 | ulladulla
# Processing Record 8 of Set 4 | springbok
# Processing Record 9 of Set 4 | kautokeino
# Processing Record 10 of Set 4 | prince rupert
# Processing Record 11 of Set 4 | taoudenni
# Processing Record 12 of Set 4 | sao jose da coroa grande
# Processing Record 13 of Set 4 | arraial do cabo
# Processing Record 14 of Set 4 | wajir
# Processing Record 15 of Set 4 | cairns
# Processing Record 16 of Set 4 | gorno-chuyskiy
# City not found. Skipping...
# Processing Record 17 of Set 4 | issa
# Processing Record 18 of Set 4 | bekovo
# Processing Record 19 of Set 4 | genhe
# Processing Record 20 of Set 4 | samusu
# City not found. Skipping...
# Processing Record 21 of Set 4 | galveston
# Processing Record 22 of Set 4 | mackenzie
# Processing Record 23 of Set 4 | oistins
# Processing Record 24 of Set 4 | saldanha
# Processing Record 25 of Set 4 | hofn
# Processing Record 26 of Set 4 | katsuura
# Processing Record 27 of Set 4 | vila velha
# Processing Record 28 of Set 4 | dawlatabad
# Processing Record 29 of Set 4 | lorengau
# Processing Record 30 of Set 4 | chokurdakh
# Processing Record 31 of Set 4 | tuktoyaktuk
# Processing Record 32 of Set 4 | tamandare
# Processing Record 33 of Set 4 | galle
# Processing Record 34 of Set 4 | hirara
# Processing Record 35 of Set 4 | daru
# Processing Record 36 of Set 4 | souillac
# Processing Record 37 of Set 4 | yola
# Processing Record 38 of Set 4 | talavera de la reina
# Processing Record 39 of Set 4 | tessalit
# Processing Record 40 of Set 4 | piacabucu
# Processing Record 41 of Set 4 | vila franca do campo
# Processing Record 42 of Set 4 | igarka
# Processing Record 43 of Set 4 | georgetown
# Processing Record 44 of Set 4 | ishigaki
# Processing Record 45 of Set 4 | bluff
# Processing Record 46 of Set 4 | olafsvik
# Processing Record 47 of Set 4 | purace
# City not found. Skipping...
# Processing Record 48 of Set 4 | qianjiang
# Processing Record 49 of Set 4 | camacupa
# Processing Record 50 of Set 4 | sao filipe
# Processing Record 1 of Set 5 | tilichiki
# Processing Record 2 of Set 5 | onokhoy
# Processing Record 3 of Set 5 | ahipara
# Processing Record 4 of Set 5 | sataua
# City not found. Skipping...
# Processing Record 5 of Set 5 | ust-kulom
# Processing Record 6 of Set 5 | castro
# Processing Record 7 of Set 5 | thompson
# Processing Record 8 of Set 5 | saint-philippe
# Processing Record 9 of Set 5 | berlevag
# Processing Record 10 of Set 5 | nome
# Processing Record 11 of Set 5 | bengkulu
# Processing Record 12 of Set 5 | farah
# Processing Record 13 of Set 5 | westport
# Processing Record 14 of Set 5 | haines junction
# Processing Record 15 of Set 5 | ketchikan
# Processing Record 16 of Set 5 | qui nhon
# Processing Record 17 of Set 5 | bambous virieux
# Processing Record 18 of Set 5 | meulaboh
# Processing Record 19 of Set 5 | otane
# Processing Record 20 of Set 5 | ballina
# Processing Record 21 of Set 5 | chuy
# Processing Record 22 of Set 5 | christchurch
# Processing Record 23 of Set 5 | beringovskiy
# Processing Record 24 of Set 5 | kargasok
# Processing Record 25 of Set 5 | tazovskiy
# Processing Record 26 of Set 5 | kodiak
# Processing Record 27 of Set 5 | cayhagan
# Processing Record 28 of Set 5 | znamenskoye
# Processing Record 29 of Set 5 | najran
# Processing Record 30 of Set 5 | tura
# Processing Record 31 of Set 5 | marzuq
# Processing Record 32 of Set 5 | luderitz
# Processing Record 33 of Set 5 | east london
# Processing Record 34 of Set 5 | klaksvik
# Processing Record 35 of Set 5 | sri aman
# Processing Record 36 of Set 5 | celestun
# Processing Record 37 of Set 5 | kavaratti
# Processing Record 38 of Set 5 | havre-saint-pierre
# Processing Record 39 of Set 5 | bilibino
# Processing Record 40 of Set 5 | talcahuano
# Processing Record 41 of Set 5 | nancha
# Processing Record 42 of Set 5 | half moon bay
# Processing Record 43 of Set 5 | bad hersfeld
# Processing Record 44 of Set 5 | harper
# Processing Record 45 of Set 5 | fortuna
# Processing Record 46 of Set 5 | muisne
# Processing Record 47 of Set 5 | marcona
# City not found. Skipping...
# Processing Record 48 of Set 5 | lasa
# Processing Record 49 of Set 5 | saint-francois
# Processing Record 50 of Set 5 | yulara
# Processing Record 1 of Set 6 | ust-kan
# Processing Record 2 of Set 6 | palu
# Processing Record 3 of Set 6 | fort myers beach
# Processing Record 4 of Set 6 | mus
# Processing Record 5 of Set 6 | port maria
# Processing Record 6 of Set 6 | kruisfontein
# Processing Record 7 of Set 6 | lakes entrance
# Processing Record 8 of Set 6 | atambua
# Processing Record 9 of Set 6 | konosha
# Processing Record 10 of Set 6 | diphu
# Processing Record 11 of Set 6 | ketou
# Processing Record 12 of Set 6 | yenagoa
# Processing Record 13 of Set 6 | trinidad
# Processing Record 14 of Set 6 | saint anthony
# Processing Record 15 of Set 6 | igrim
# Processing Record 16 of Set 6 | sur
# Processing Record 17 of Set 6 | nyurba
# Processing Record 18 of Set 6 | balkhash
# Processing Record 19 of Set 6 | lerwick
# Processing Record 20 of Set 6 | barentsburg
# City not found. Skipping...
# Processing Record 21 of Set 6 | trairi
# Processing Record 22 of Set 6 | dunedin
# Processing Record 23 of Set 6 | antsohihy
# Processing Record 24 of Set 6 | san patricio
# Processing Record 25 of Set 6 | belle glade
# Processing Record 26 of Set 6 | huadian
# Processing Record 27 of Set 6 | marawi
# Processing Record 28 of Set 6 | santa cruz del sur
# Processing Record 29 of Set 6 | haapiti
# Processing Record 30 of Set 6 | seddon
# Processing Record 31 of Set 6 | sobolevo
# Processing Record 32 of Set 6 | ilheus
# Processing Record 33 of Set 6 | coihaique
# Processing Record 34 of Set 6 | taikang
# Processing Record 35 of Set 6 | tuatapere
# Processing Record 36 of Set 6 | ngunguru
# Processing Record 37 of Set 6 | puerto padre
# Processing Record 38 of Set 6 | vestmanna
# Processing Record 39 of Set 6 | torbay
# Processing Record 40 of Set 6 | floro
# Processing Record 41 of Set 6 | tsaratanana
# Processing Record 42 of Set 6 | bundaberg
# Processing Record 43 of Set 6 | okato
# Processing Record 44 of Set 6 | samarai
# Processing Record 45 of Set 6 | rocha
# Processing Record 46 of Set 6 | chabahar
# Processing Record 47 of Set 6 | meadow lake
# Processing Record 48 of Set 6 | florence
# Processing Record 49 of Set 6 | santa lucia
# Processing Record 50 of Set 6 | road town
# Processing Record 1 of Set 7 | ugoofaaru
# Processing Record 2 of Set 7 | cholet
# Processing Record 3 of Set 7 | laborie
# Processing Record 4 of Set 7 | masjed-e soleyman
# City not found. Skipping...
# Processing Record 5 of Set 7 | lavrentiya
# Processing Record 6 of Set 7 | cidreira
# Processing Record 7 of Set 7 | saint-louis
# Processing Record 8 of Set 7 | luena
# Processing Record 9 of Set 7 | lar
# Processing Record 10 of Set 7 | douglas
# Processing Record 11 of Set 7 | khomeynishahr
# City not found. Skipping...
# Processing Record 12 of Set 7 | shablykino
# Processing Record 13 of Set 7 | hay river
# Processing Record 14 of Set 7 | sarny
# Processing Record 15 of Set 7 | kaitangata
# Processing Record 16 of Set 7 | lagoa
# Processing Record 17 of Set 7 | sorong
# Processing Record 18 of Set 7 | mikun
# Processing Record 19 of Set 7 | constitucion
# Processing Record 20 of Set 7 | kanpur
# Processing Record 21 of Set 7 | urucara
# Processing Record 22 of Set 7 | piterka
# Processing Record 23 of Set 7 | palembang
# Processing Record 24 of Set 7 | cordoba
# Processing Record 25 of Set 7 | lumeje
# Processing Record 26 of Set 7 | bouna
# Processing Record 27 of Set 7 | crotone
# Processing Record 28 of Set 7 | payo
# Processing Record 29 of Set 7 | saint-augustin
# Processing Record 30 of Set 7 | el faiyum
# City not found. Skipping...
# Processing Record 31 of Set 7 | axim
# Processing Record 32 of Set 7 | verkhnetulomskiy
# Processing Record 33 of Set 7 | banmo
# City not found. Skipping...
# Processing Record 34 of Set 7 | san cristobal
# Processing Record 35 of Set 7 | novopokrovka
# Processing Record 36 of Set 7 | aromashevo
# Processing Record 37 of Set 7 | kikwit
# Processing Record 38 of Set 7 | moussoro
# Processing Record 39 of Set 7 | tahe
# Processing Record 40 of Set 7 | geraldton
# Processing Record 41 of Set 7 | portland
# Processing Record 42 of Set 7 | plainview
# Processing Record 43 of Set 7 | killybegs
# Processing Record 44 of Set 7 | odweyne
# Processing Record 45 of Set 7 | kedrovyy
# Processing Record 46 of Set 7 | sakakah
# Processing Record 47 of Set 7 | amderma
# City not found. Skipping...
# Processing Record 48 of Set 7 | vreed en hoop
# City not found. Skipping...
# Processing Record 49 of Set 7 | umzimvubu
# City not found. Skipping...
# Processing Record 50 of Set 7 | lufilufi
# Processing Record 1 of Set 8 | nouadhibou
# Processing Record 2 of Set 8 | newport
# Processing Record 3 of Set 8 | meyungs
# City not found. Skipping...
# Processing Record 4 of Set 8 | alamosa
# Processing Record 5 of Set 8 | kaoma
# Processing Record 6 of Set 8 | avera
# Processing Record 7 of Set 8 | travagliato
# Processing Record 8 of Set 8 | businga
# Processing Record 9 of Set 8 | kavieng
# Processing Record 10 of Set 8 | kudahuvadhoo
# Processing Record 11 of Set 8 | bathsheba
# Processing Record 12 of Set 8 | cravo norte
# Processing Record 13 of Set 8 | tarbagatay
# Processing Record 14 of Set 8 | torata
# Processing Record 15 of Set 8 | tyrma
# Processing Record 16 of Set 8 | chajul
# Processing Record 17 of Set 8 | port-gentil
# Processing Record 18 of Set 8 | teberda
# Processing Record 19 of Set 8 | henties bay
# Processing Record 20 of Set 8 | litovko
# Processing Record 21 of Set 8 | toliary
# City not found. Skipping...
# Processing Record 22 of Set 8 | ust-nera
# Processing Record 23 of Set 8 | tumannyy
# City not found. Skipping...
# Processing Record 24 of Set 8 | aksu
# Processing Record 25 of Set 8 | tosya
# Processing Record 26 of Set 8 | harlingen
# Processing Record 27 of Set 8 | saleaula
# City not found. Skipping...
# Processing Record 28 of Set 8 | peru
# Processing Record 29 of Set 8 | yantal
# Processing Record 30 of Set 8 | vardo
# Processing Record 31 of Set 8 | kupang
# Processing Record 32 of Set 8 | begoro
# Processing Record 33 of Set 8 | plettenberg bay
# Processing Record 34 of Set 8 | nishihara
# Processing Record 35 of Set 8 | leshukonskoye
# Processing Record 36 of Set 8 | sioux lookout
# Processing Record 37 of Set 8 | grand gaube
# Processing Record 38 of Set 8 | vrangel
# Processing Record 39 of Set 8 | warwick
# Processing Record 40 of Set 8 | vizinga
# Processing Record 41 of Set 8 | asbe teferi
# Processing Record 42 of Set 8 | monte cristi
# City not found. Skipping...
# Processing Record 43 of Set 8 | bambanglipuro
# Processing Record 44 of Set 8 | kamenskoye
# City not found. Skipping...
# Processing Record 45 of Set 8 | humaita
# Processing Record 46 of Set 8 | annecy-le-vieux
# Processing Record 47 of Set 8 | washington
# Processing Record 48 of Set 8 | riyadh
# Processing Record 49 of Set 8 | melhus
# Processing Record 50 of Set 8 | vokhtoga
# Processing Record 1 of Set 9 | comodoro rivadavia
# Processing Record 2 of Set 9 | russell
# Processing Record 3 of Set 9 | dahuk
# Processing Record 4 of Set 9 | attawapiskat
# City not found. Skipping...
# Processing Record 5 of Set 9 | iracoubo
# Processing Record 6 of Set 9 | maldonado
# Processing Record 7 of Set 9 | kulhudhuffushi
# Processing Record 8 of Set 9 | inuvik
# Processing Record 9 of Set 9 | northam
# Processing Record 10 of Set 9 | roma
# Processing Record 11 of Set 9 | zhangjiakou
# Processing Record 12 of Set 9 | prosperidad
# Processing Record 13 of Set 9 | coquimbo
# Processing Record 14 of Set 9 | mehriz
# Processing Record 15 of Set 9 | hare bay
# Processing Record 16 of Set 9 | beruwala
# Processing Record 17 of Set 9 | cervo
# Processing Record 18 of Set 9 | college
# Processing Record 19 of Set 9 | corinto
# Processing Record 20 of Set 9 | tadine
# Processing Record 21 of Set 9 | ramgarh
# Processing Record 22 of Set 9 | itaporanga
# Processing Record 23 of Set 9 | hurricane
# Processing Record 24 of Set 9 | gulshat
# City not found. Skipping...
# Processing Record 25 of Set 9 | myrtle beach
# Processing Record 26 of Set 9 | jogindarnagar
# Processing Record 27 of Set 9 | deh rawud
# City not found. Skipping...
# Processing Record 28 of Set 9 | aksarka
# Processing Record 29 of Set 9 | umtata
# Processing Record 30 of Set 9 | rajpura
# Processing Record 31 of Set 9 | tiznit
# Processing Record 32 of Set 9 | casablanca
# Processing Record 33 of Set 9 | moose factory
# Processing Record 34 of Set 9 | owando
# Processing Record 35 of Set 9 | amahai
# Processing Record 36 of Set 9 | kalnibolotskaya
# Processing Record 37 of Set 9 | oranjemund
# Processing Record 38 of Set 9 | athabasca
# Processing Record 39 of Set 9 | nguruka
# Processing Record 40 of Set 9 | chitral
# Processing Record 41 of Set 9 | grand river south east
# City not found. Skipping...
# Processing Record 42 of Set 9 | inhambane
# Processing Record 43 of Set 9 | mersing
# Processing Record 44 of Set 9 | whitianga
# Processing Record 45 of Set 9 | north bend
# Processing Record 46 of Set 9 | mayumba
# Processing Record 47 of Set 9 | karonga
# Processing Record 48 of Set 9 | leningradskiy
# Processing Record 49 of Set 9 | guerrero negro
# Processing Record 50 of Set 9 | pangody
# Processing Record 1 of Set 10 | arang
# Processing Record 2 of Set 10 | ruatoria
# City not found. Skipping...
# Processing Record 3 of Set 10 | njombe
# Processing Record 4 of Set 10 | codrington
# Processing Record 5 of Set 10 | jacmel
# Processing Record 6 of Set 10 | port jervis
# Processing Record 7 of Set 10 | santa isabel do rio negro
# Processing Record 8 of Set 10 | brae
# Processing Record 9 of Set 10 | batemans bay
# Processing Record 10 of Set 10 | berberati
# Processing Record 11 of Set 10 | caravelas
# Processing Record 12 of Set 10 | opuwo
# Processing Record 13 of Set 10 | hobyo
# Processing Record 14 of Set 10 | nikki
# Processing Record 15 of Set 10 | acarau
# Processing Record 16 of Set 10 | tabas
# Processing Record 17 of Set 10 | tocopilla
# Processing Record 18 of Set 10 | richards bay
# Processing Record 19 of Set 10 | severnyy
# Processing Record 20 of Set 10 | baykit
# Processing Record 21 of Set 10 | sinnamary
# Processing Record 22 of Set 10 | bandarbeyla
# Processing Record 23 of Set 10 | solnechnyy
# Processing Record 24 of Set 10 | touba
# Processing Record 25 of Set 10 | khasan
# Processing Record 26 of Set 10 | usinsk
# Processing Record 27 of Set 10 | samana
# Processing Record 28 of Set 10 | warrnambool
# Processing Record 29 of Set 10 | sumkino
# Processing Record 30 of Set 10 | sembe
# Processing Record 31 of Set 10 | marsh harbour
# Processing Record 32 of Set 10 | halalo
# City not found. Skipping...
# Processing Record 33 of Set 10 | chunoyar
# Processing Record 34 of Set 10 | pisco
# Processing Record 35 of Set 10 | aksarayskiy
# Processing Record 36 of Set 10 | the pas
# Processing Record 37 of Set 10 | valera
# Processing Record 38 of Set 10 | malakal
# Processing Record 39 of Set 10 | komsomolskiy
# Processing Record 40 of Set 10 | allende
# Processing Record 41 of Set 10 | guaruja
# Processing Record 42 of Set 10 | honiara
# Processing Record 43 of Set 10 | marquette
# Processing Record 44 of Set 10 | hollister
# Processing Record 45 of Set 10 | urdzhar
# City not found. Skipping...
# Processing Record 46 of Set 10 | cherskiy
# Processing Record 47 of Set 10 | dubai
# Processing Record 48 of Set 10 | dien bien
# City not found. Skipping...
# Processing Record 49 of Set 10 | mareeba
# Processing Record 50 of Set 10 | mao
# Processing Record 1 of Set 11 | whitehorse
# Processing Record 2 of Set 11 | palabuhanratu
# City not found. Skipping...
# Processing Record 3 of Set 11 | japura
# Processing Record 4 of Set 11 | polonnaruwa
# Processing Record 5 of Set 11 | belleville
# Processing Record 6 of Set 11 | coolum beach
# Processing Record 7 of Set 11 | sesheke
# Processing Record 8 of Set 11 | kismayo
# Processing Record 9 of Set 11 | nandu
# Processing Record 10 of Set 11 | novikovo
# Processing Record 11 of Set 11 | bilma
# Processing Record 12 of Set 11 | pavlodar
# Processing Record 13 of Set 11 | aykhal
# Processing Record 14 of Set 11 | sumbe
# Processing Record 15 of Set 11 | nieuw amsterdam
# Processing Record 16 of Set 11 | bargal
# City not found. Skipping...
# Processing Record 17 of Set 11 | nadvoitsy
# Processing Record 18 of Set 11 | yumen
# Processing Record 19 of Set 11 | san carlos de bariloche
# Processing Record 20 of Set 11 | kilimatinde
# Processing Record 21 of Set 11 | baruun-urt
# Processing Record 22 of Set 11 | ploemeur
# Processing Record 23 of Set 11 | alexandria
# Processing Record 24 of Set 11 | surt
# Processing Record 25 of Set 11 | taitung
# Processing Record 26 of Set 11 | pascagoula
# Processing Record 27 of Set 11 | ciudad bolivar
# Processing Record 28 of Set 11 | corrales
# Processing Record 29 of Set 11 | kaele
# Processing Record 30 of Set 11 | sainte-suzanne
# Processing Record 31 of Set 11 | toguchin
# Processing Record 32 of Set 11 | bayevo
# Processing Record 33 of Set 11 | sennoy
# Processing Record 34 of Set 11 | saint-pierre
# Processing Record 35 of Set 11 | da nang
# Processing Record 36 of Set 11 | sikonge
# Processing Record 37 of Set 11 | bay roberts
# Processing Record 38 of Set 11 | formosa
# Processing Record 39 of Set 11 | ovalle
# Processing Record 40 of Set 11 | rungata
# City not found. Skipping...
# Processing Record 41 of Set 11 | skalistyy
# City not found. Skipping...
# Processing Record 42 of Set 11 | cabo san lucas
# Processing Record 43 of Set 11 | mount vernon
# Processing Record 44 of Set 11 | kassala
# Processing Record 45 of Set 11 | porto santo
# Processing Record 46 of Set 11 | evensk
# Processing Record 47 of Set 11 | oksfjord
# Processing Record 48 of Set 11 | mitsamiouli
# Processing Record 49 of Set 11 | xiongyue
# Processing Record 50 of Set 11 | nhulunbuy
# Processing Record 1 of Set 12 | port blair
# Processing Record 2 of Set 12 | kumluca
# Processing Record 3 of Set 12 | encheng
# Processing Record 4 of Set 12 | sao joao da barra
# Processing Record 5 of Set 12 | terek
# Processing Record 6 of Set 12 | akdepe
# Processing Record 7 of Set 12 | tchibanga
# Processing Record 8 of Set 12 | porbandar
# Processing Record 9 of Set 12 | kitimat
# Processing Record 10 of Set 12 | borba
# Processing Record 11 of Set 12 | mount isa
# Processing Record 12 of Set 12 | allonnes
# Processing Record 13 of Set 12 | talara
# Processing Record 14 of Set 12 | san jose
# Processing Record 15 of Set 12 | asau
# Processing Record 16 of Set 12 | mahajanga
# Processing Record 17 of Set 12 | sosnovka
# Processing Record 18 of Set 12 | la ronge
# Processing Record 19 of Set 12 | emirdag
# Processing Record 20 of Set 12 | thunder bay
# Processing Record 21 of Set 12 | chifeng
# Processing Record 22 of Set 12 | ust-kuyga
# Processing Record 23 of Set 12 | kargil
# Processing Record 24 of Set 12 | alice springs
# Processing Record 25 of Set 12 | tari
# Processing Record 26 of Set 12 | pozo colorado
# Processing Record 27 of Set 12 | poronaysk
# Processing Record 28 of Set 12 | zhoucheng
# Processing Record 29 of Set 12 | churapcha
# Processing Record 30 of Set 12 | ipixuna
# Processing Record 31 of Set 12 | mpika
# Processing Record 32 of Set 12 | akyab
# Processing Record 33 of Set 12 | rantauprapat
# Processing Record 34 of Set 12 | rio grande
# Processing Record 35 of Set 12 | puerto penasco
# Processing Record 36 of Set 12 | faanui
# Processing Record 37 of Set 12 | makakilo city
# Processing Record 38 of Set 12 | palmer
# Processing Record 39 of Set 12 | yerbogachen
# Processing Record 40 of Set 12 | azle
# Processing Record 41 of Set 12 | mount pleasant
# Processing Record 42 of Set 12 | waipawa
# Processing Record 43 of Set 12 | la crosse
# Processing Record 44 of Set 12 | rawson
# Processing Record 45 of Set 12 | la asuncion
# Processing Record 46 of Set 12 | benton harbor
# Processing Record 47 of Set 12 | mbandaka
# Processing Record 48 of Set 12 | havelock
# Processing Record 49 of Set 12 | neokhorion
# Processing Record 50 of Set 12 | bonfim
# Processing Record 1 of Set 13 | newton
# Processing Record 2 of Set 13 | kokopo
# Processing Record 3 of Set 13 | gorontalo
# Processing Record 4 of Set 13 | aitape
# Processing Record 5 of Set 13 | la rioja
# Processing Record 6 of Set 13 | moerai
# Processing Record 7 of Set 13 | qasigiannguit
# Processing Record 8 of Set 13 | uyar
# Processing Record 9 of Set 13 | namtsy
# Processing Record 10 of Set 13 | ohafia
# Processing Record 11 of Set 13 | kingaroy
# Processing Record 12 of Set 13 | wahpeton
# Processing Record 13 of Set 13 | broome
# Processing Record 14 of Set 13 | pringsewu
# Processing Record 15 of Set 13 | vestmannaeyjar
# Processing Record 16 of Set 13 | batagay-alyta
# Processing Record 17 of Set 13 | udachnyy
# Processing Record 18 of Set 13 | camacha
# Processing Record 19 of Set 13 | mokhsogollokh
# Processing Record 20 of Set 13 | walvis bay
# Processing Record 21 of Set 13 | okahandja
# Processing Record 22 of Set 13 | jumla
# Processing Record 23 of Set 13 | castelo do piaui
# Processing Record 24 of Set 13 | londa
# Processing Record 25 of Set 13 | sentyabrskiy
# City not found. Skipping...
# Processing Record 26 of Set 13 | sorvag
# City not found. Skipping...
# Processing Record 27 of Set 13 | inta
# Processing Record 28 of Set 13 | mansfield
# Processing Record 29 of Set 13 | laguna
# Processing Record 30 of Set 13 | maghama
# City not found. Skipping...
# Processing Record 31 of Set 13 | nizhnyaya poyma
# Processing Record 32 of Set 13 | adelaide
# Processing Record 33 of Set 13 | lamar
# Processing Record 34 of Set 13 | nyuksenitsa
# Processing Record 35 of Set 13 | fort beaufort
# Processing Record 36 of Set 13 | bonavista
# Processing Record 37 of Set 13 | jalingo
# Processing Record 38 of Set 13 | belmonte
# Processing Record 39 of Set 13 | acari
# Processing Record 40 of Set 13 | we
# City not found. Skipping...
# Processing Record 41 of Set 13 | lucknow
# Processing Record 42 of Set 13 | salinas
# Processing Record 43 of Set 13 | falealupo
# City not found. Skipping...
# Processing Record 44 of Set 13 | urengoy
# Processing Record 45 of Set 13 | yaan
# Processing Record 46 of Set 13 | chester
# Processing Record 47 of Set 13 | dauriya
# Processing Record 48 of Set 13 | rusape
# Processing Record 49 of Set 13 | mandera
# Processing Record 50 of Set 13 | buqayq
# City not found. Skipping...
# Processing Record 1 of Set 14 | anadyr
# Processing Record 2 of Set 14 | aden
# Processing Record 3 of Set 14 | bull savanna
# Processing Record 4 of Set 14 | vao
# Processing Record 5 of Set 14 | veraval
# Processing Record 6 of Set 14 | kaeo
# Processing Record 7 of Set 14 | iwaki
# Processing Record 8 of Set 14 | bollnas
# Processing Record 9 of Set 14 | letlhakane
# Processing Record 10 of Set 14 | yeniseysk
# Processing Record 11 of Set 14 | hemnesberget
# Processing Record 12 of Set 14 | talesh
# City not found. Skipping...
# Processing Record 13 of Set 14 | timmins
# Processing Record 14 of Set 14 | ilukste
# Processing Record 15 of Set 14 | tual
# Processing Record 16 of Set 14 | namanga
# Processing Record 17 of Set 14 | santa maria
# Processing Record 18 of Set 14 | stokmarknes
# Processing Record 19 of Set 14 | ust-maya
# Processing Record 20 of Set 14 | warrington
# Processing Record 21 of Set 14 | puro
# Processing Record 22 of Set 14 | wukari
# Processing Record 23 of Set 14 | esso
# Processing Record 24 of Set 14 | namatanai
# Processing Record 25 of Set 14 | ekhabi
# Processing Record 26 of Set 14 | marmaron
# City not found. Skipping...
# Processing Record 27 of Set 14 | hami
# Processing Record 28 of Set 14 | mae sai
# Processing Record 29 of Set 14 | kungurtug
# Processing Record 30 of Set 14 | kununurra
# Processing Record 31 of Set 14 | ustye
# Processing Record 32 of Set 14 | grande-riviere
# City not found. Skipping...
# Processing Record 33 of Set 14 | san policarpo
# Processing Record 34 of Set 14 | benin
# Processing Record 35 of Set 14 | ulaangom
# Processing Record 36 of Set 14 | bahia blanca
# Processing Record 37 of Set 14 | pontianak
# Processing Record 38 of Set 14 | ferrol
# Processing Record 39 of Set 14 | grimari
# City not found. Skipping...
# Processing Record 40 of Set 14 | conde
# Processing Record 41 of Set 14 | denpasar
# Processing Record 42 of Set 14 | williston
# Processing Record 43 of Set 14 | damavand
# Processing Record 44 of Set 14 | port hardy
# Processing Record 45 of Set 14 | gainesville
# Processing Record 46 of Set 14 | alofi
# Processing Record 47 of Set 14 | atar
# Processing Record 48 of Set 14 | moyale
# Processing Record 49 of Set 14 | lake city
# Processing Record 50 of Set 14 | umm lajj
# Processing Record 1 of Set 15 | ahuimanu
# Processing Record 2 of Set 15 | takoradi
# Processing Record 3 of Set 15 | brisbane
# Processing Record 4 of Set 15 | honningsvag
# Processing Record 5 of Set 15 | puerto baquerizo moreno
# Processing Record 6 of Set 15 | tutoia
# Processing Record 7 of Set 15 | ust-tsilma
# Processing Record 8 of Set 15 | ewa beach
# Processing Record 9 of Set 15 | peterhead
# Processing Record 10 of Set 15 | bullhead city
# Processing Record 11 of Set 15 | moiyabana
# City not found. Skipping...
# Processing Record 12 of Set 15 | petrokamenskoye
# Processing Record 13 of Set 15 | karratha
# Processing Record 14 of Set 15 | guilin
# Processing Record 15 of Set 15 | shubarkuduk
# Processing Record 16 of Set 15 | safford
# Processing Record 17 of Set 15 | maningrida
# Processing Record 18 of Set 15 | denison
# Processing Record 19 of Set 15 | nuuk
# Processing Record 20 of Set 15 | ust-kamchatsk
# City not found. Skipping...
# Processing Record 21 of Set 15 | williams lake
# Processing Record 22 of Set 15 | priargunsk
# Processing Record 23 of Set 15 | caucaia
# Processing Record 24 of Set 15 | drogheda
# Processing Record 25 of Set 15 | silver city
# Processing Record 26 of Set 15 | helong
# Processing Record 27 of Set 15 | shenjiamen
# Processing Record 28 of Set 15 | nadym
# Processing Record 29 of Set 15 | poum
# Processing Record 30 of Set 15 | helena
# Processing Record 31 of Set 15 | korcula
# Processing Record 32 of Set 15 | gari
# Processing Record 33 of Set 15 | dongsheng
# Processing Record 34 of Set 15 | skibbereen
# Processing Record 35 of Set 15 | illela
# Processing Record 36 of Set 15 | nanortalik
# Processing Record 37 of Set 15 | thongwa
# Processing Record 38 of Set 15 | fengzhen
# Processing Record 39 of Set 15 | umm durman
# City not found. Skipping...
# Processing Record 40 of Set 15 | kutum
# Processing Record 41 of Set 15 | raudeberg
# Processing Record 42 of Set 15 | uva
# Processing Record 43 of Set 15 | valparaiso
# Processing Record 44 of Set 15 | miyazu
# Processing Record 45 of Set 15 | abidjan
# Processing Record 46 of Set 15 | tshikapa
# Processing Record 47 of Set 15 | sabaudia
# Processing Record 48 of Set 15 | beloha
# Processing Record 49 of Set 15 | bandar-e lengeh
# Processing Record 50 of Set 15 | ossora
# Processing Record 1 of Set 16 | hamilton
# Processing Record 2 of Set 16 | flin flon
# Processing Record 3 of Set 16 | ucluelet
# Processing Record 4 of Set 16 | kenai
# Processing Record 5 of Set 16 | marshfield
# Processing Record 6 of Set 16 | alotau
# City not found. Skipping...
# Processing Record 7 of Set 16 | sao felix do xingu
# Processing Record 8 of Set 16 | kaspiyskiy
# Processing Record 9 of Set 16 | sinegorye
# Processing Record 10 of Set 16 | ellisras
# Processing Record 11 of Set 16 | ji-parana
# City not found. Skipping...
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
len(city_data)
# Out:
# 702

# %%
# Convert the array of dictionaries to a Pandas DataFrame.
vacation_city_data_df = pd.DataFrame(city_data)
vacation_city_data_df.head(10)
# Out:
#            City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0      Kirkwall  58.9848   -2.9587     43.14        81          75
# 1        Jardim -21.4803  -56.1381     83.88        34          64
# 2         Kapaa  22.0752 -159.3190     71.92        74          20
# 3   Pangnirtung  66.1451  -65.7125    -29.20        62          75
# 4     Busselton -33.6500  115.3333     62.10        68          86
# 5       Rikitea -23.1203 -134.9692     77.94        77           4
# 6  Punta Arenas -53.1500  -70.9167     57.22        93           0
# 7         Airai  -8.9266  125.4092     62.15        94          97
# 8       Te Anau -45.4167  167.7167     45.43        87           1
# 9          Lata  40.1629   -8.3327     70.07        36           0
#
#    Wind Speed Country Current Description
# 0       19.57      GB       broken clouds
# 1        6.44      BR       broken clouds
# 2       14.97      US          few clouds
# 3        5.75      CA       broken clouds
# 4        9.53      AU     overcast clouds
# 5       13.71      PF          light rain
# 6        8.05      CL           clear sky
# 7        1.99      TL     overcast clouds
# 8        1.97      NZ           clear sky
# 9        4.56      PT           clear sky

# %%
new_column_order = ["City", "Country", "Lat","Lng","Max Temp", "Humidity", "Cloudiness","Wind Speed", "Current Description"]
vacation_city_data_df = vacation_city_data_df[new_column_order]
vacation_city_data_df.head(10)
# Out:
#            City Country      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0      Kirkwall      GB  58.9848   -2.9587     43.14        81          75
# 1        Jardim      BR -21.4803  -56.1381     83.88        34          64
# 2         Kapaa      US  22.0752 -159.3190     71.92        74          20
# 3   Pangnirtung      CA  66.1451  -65.7125    -29.20        62          75
# 4     Busselton      AU -33.6500  115.3333     62.10        68          86
# 5       Rikitea      PF -23.1203 -134.9692     77.94        77           4
# 6  Punta Arenas      CL -53.1500  -70.9167     57.22        93           0
# 7         Airai      TL  -8.9266  125.4092     62.15        94          97
# 8       Te Anau      NZ -45.4167  167.7167     45.43        87           1
# 9          Lata      PT  40.1629   -8.3327     70.07        36           0
#
#    Wind Speed Current Description
# 0       19.57       broken clouds
# 1        6.44       broken clouds
# 2       14.97          few clouds
# 3        5.75       broken clouds
# 4        9.53     overcast clouds
# 5       13.71          light rain
# 6        8.05           clear sky
# 7        1.99     overcast clouds
# 8        1.97           clear sky
# 9        4.56           clear sky

# %%
# Create the output file (CSV).
output_data_file = "Weather_Database/WeatherPy_Database.csv"
# Export the City_Data into a CSV.
vacation_city_data_df.to_csv(output_data_file, index_label="City_ID")
